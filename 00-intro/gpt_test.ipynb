# %%
# %pip install openai

# %%
prompt="""
# 한국 애플 앱스토어 무료 인기 어플 순위 알려줘.
"""

from openai import OpenAI
client = OpenAI(api_key='sk-')

response = client.responses.create(
    # model='gpt-4.1-nano',
    # model='gpt-5.2',
    model='o4-mini',
    input=prompt
)

print(response.output_text)
