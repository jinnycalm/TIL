# %% [markdown]
# # 06 OOP (Object Oriented Programming)

# %%
# 원 (Circle)
class Circle:
    # 생성자함수 -> 처음 인스턴스가 만들어질 때 자동 호출되는 함수.
    def __init__(self, r):
        self.r = r
        print(f'반지름이 {self.r}인 원이 생성되었습니다.')

    def get_area(self):
        return 3.14 * self.r**2
    
    def __add__(self, other):
        return Circle(self.r + other.r)

c1 = Circle(3) # 반지름이 3인 원
c2 = Circle(5) # 반지름이 5인 원

print(c1.get_area()) # 반지름이 3인 원의 넒이
print(c2.get_area()) # 반지름이 5인 원의 넒이

c3 = c1 + c2 # r=3 + r=5 -> r=8 원을 새롭게 만들겠다.
c3.get_area()
# Out:
# 반지름이 3인 원이 생성되었습니다.
# 반지름이 5인 원이 생성되었습니다.
# 28.26
# 78.5
# 반지름이 8인 원이 생성되었습니다.
# 200.96

# %% [markdown]
# - C# : 윈도우에서 많이 쓰임
# - Objective C: 애플쪽에서 쓰다가 swift로 바뀜
#
# - C 언어는 절차지향 언어. 절차 지향은 좀 불편하다 -> 객체 지향 언어가 생김
# - C++

# %% [markdown]
# ## Programming 언어는 인간이 만든 것. 인간 입장에서 편하기 위해서 만든것.
#
# 프로그래밍 언어도 어떤 구간에서는 기계어가 되어야 함. 컴터가 알아듣기 위해서는. 이 순간이 언제냐?
# 1. 코드가 다 작성이 되면 한번에 몰아서 기계어로 바꿈. (컴파일러 언어 -ex. c c++) 더 빠르긴 함.
# 2. 한줄씩 실시간으로 바꾸면서 실행함. (인터프리터 언어 - ex. python, JS)
#
# ### OOP(객체지향언어) -> 실존하는 값이 주인공이다.
# - Object: 객체: 값 (`1`, `'abc'`, `[1, 2, 3]`)
# - Oriented: 지향 : 핵심, 주인공
#
# - Class - Instance

# %% [markdown]
# 서양철학은 A 이후로 많은 담론이 있었지만, A에 대한 주석일 뿐이다.
# 다만 B가 등장하기 전까지는
#
# A = 플라톤
# B =
#
# 플라톤의 이데아. 본질은 따로 있고 우리가 보는 현실은 진짜가 아니다.
# 이데아에서 파생된 무언가가 있음.

# %%
# Person
# 키, 몸무게, 나이, 이름
# 인사, 공부

# Pokemon
# 피카츄가 몇 마리가 있죠? 100마리가 나올 수도 있음 피카츄 1,2,3 이런애들이 있어도 피카츄 원형이라는게 있고 그 실체가 여러개가 있는 것.
# 원형따로 실체따로.
# 피카츄(개념) - 피카츄123(실체)
# 의자(개념) - 의자 A,B,C (실체)

# %%
# phthon에서 클래스 이름은 PascalCase로 짓는다.

class Person:
    # 1. 특성(attribute)
    height = 165
    weigh = 55
    age = 20
    iq = 100
    name = '인간'

    # 2. 행동(method)
    def greeting(self):
        return f'안녕하세요, {self.name}입니다. {self.age}살 입니다.'

    def study(self):
        self.iq += 5

# %%
# Person 개념적 대상을 -> 실제 생성
p1 = Person()
p2 = Person()

# %%
# 특성
p1.age = 30
p1.name = '김로봇'
p1.weight = 80
p1.height = 230
# 행동
p1.greeting()
# Out:
# '안녕하세요, 김로봇입니다. 30살 입니다.'

# %%
# 특성
p2.age = 23
p2.name = '박사람'
p2.weight = 45
p2.height = 155
# 행동
p2.greeting()
# Out:
# '안녕하세요, 박사람입니다. 23살 입니다.'

# %%
# 개념적인 인간을 뽑아내고 p1, p2를 각각 속성을 바꿔서 세팅하였음. 완전 다른 존재가 된거임.
# 개념이 class, 실존하는 실체가 instance라는 이름으로 불리고 있는 것.

# OOP 프로그래밍 탄생 이유 => 현실세계 반영하기 위해서.
# 실존하는 인물들은 상위에 idea라는 것이 있음.

# 순수 객체 지향
# 모든 값은 다 객체다.

# %% [markdown]
# -  개념적인 인간을 뽑아내고 p1, p2를 각각 속성을 바꿔서 세팅하였음. 완전 다른 존재가 된거임.
# - 개념이 class, 실존하는 실체가 instance라는 이름으로 불리고 있는 것.
#
# - OOP 프로그래밍 탄생 이유 => 현실세계 반영하기 위해서.
# - 실존하는 인물들은 상위에 idea라는 것이 있음.
#
# - 순수 객체 지향
# - 모든 값은 다 객체다. 12345 는 모두 int [1, 2, 3]은 list
# `class int:
#     pass`
# `class list:
#     pass`

# %%
r1 = range(100) # range 클래스의 인스턴스를 만든다.
l1 = list(r1) # list 클래스의 인스턴스를 만든다.

'abc' # string 클래스의 인스턴스 -> str임

a = 2/1
type('abc')
# Out:
# str

# %%
# 객체 지향 세상 -> 객체들끼리 상호작용(메서드) 하는 세상
# int 클래스 1과 int 클래스 2가 상호작용해서 3이 되었다.
# 주어 뒤어 . 하고 함수 호출하는게 메서드임.

# 근데 1+2는 주어.동사가 아니라 연산자임.
1 + 2
# (1).__add__(2) 이렇게 생겼음 실제로는.
(2).__add__(3)

(3).__gt__(2)
# Out:
# True
